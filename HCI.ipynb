# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardojbl/HAR/blob/master/HCI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Using a Free GPU Runtime
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0

# %%
# Install Keras with pip
# !pip install -q keras
import keras
# Out:
# Using TensorFlow backend.

# %%
# Install GraphViz with apt
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
import numpy as np
import pandas as pd
#import train.csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74a8d656-0bed-4216-807a-e850d7bd97e4" name="files[]" multiple disabled />
#      <output id="result-74a8d656-0bed-4216-807a-e850d7bd97e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
train_data = pd.read_csv("train.csv")
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.288585          -0.020294  ...        1  STANDING
# 1           0.278419          -0.016411  ...        1  STANDING
# 2           0.279653          -0.019467  ...        1  STANDING
# 3           0.279174          -0.026201  ...        1  STANDING
# 4           0.276629          -0.016570  ...        1  STANDING
#
# [5 rows x 563 columns]

# %%
train_data.Activity.value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
train_data.shape
# Out:
# (7352, 563)

# %%
#import train.csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5fba7d7-d44a-4850-b146-0007620032d6" name="files[]" multiple disabled />
#      <output id="result-e5fba7d7-d44a-4850-b146-0007620032d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
test_data = pd.read_csv("test.csv")
test_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.257178          -0.023285  ...        2  STANDING
# 1           0.286027          -0.013163  ...        2  STANDING
# 2           0.275485          -0.026050  ...        2  STANDING
# 3           0.270298          -0.032614  ...        2  STANDING
# 4           0.274833          -0.027848  ...        2  STANDING
#
# [5 rows x 563 columns]

# %%
#shufflingdata ()
from sklearn.utils import shuffle

#test = shuffle(test)
train_data = shuffle(train_data)

# %%
#separating data inputs and outputs labels
trainData = train_data.drop('Activity' , axis=1).values
trainLabel = train_data.Activity.values

testData = test_data.drop('Activity' , axis=1).values
testLabel = test_data.Activity.values

# %%
#encoding labels
from sklearn import preprocessing

encoder = preprocessing.LabelEncoder()

#encoding test labels
encoder.fit(testLabel)
testLabelE = encoder.transform(testLabel)

#encoding train labels
encoder.fit(trainLabel)
trainLabelE = encoder.transform(trainLabel)

# %%
testLabelE
# Out:
# array([2, 2, 2, ..., 5, 5, 5])
